# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# 3. Create a new set of 2,000 random latitides and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
 
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# 4. Identify the nearest city for each latitude and longitdue 
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #If the city is unique, then we'll add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# 5. Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city.
query_url = url + "appid=" + weather_api_key + "&q=" + city

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %%
weather_json.keys()
# Out:
# dict_keys(['cod', 'message'])

# %%
weather_json.get("main")

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60add0a32a339d55a250a3a564f4f4d5'

# %%
# 6. Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i].replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {cities[i]}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
      
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": cities[i],
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | sumter
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | arlit
# Processing Record 11 of Set 1 | ajaccio
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | cockburn town
# Processing Record 14 of Set 1 | zwedru
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | yulara
# Processing Record 17 of Set 1 | pauini
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 1 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | kjopsvik
# Processing Record 23 of Set 1 | baiyin
# Processing Record 24 of Set 1 | enugu
# Processing Record 25 of Set 1 | iracoubo
# Processing Record 26 of Set 1 | egvekinot
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | batemans bay
# Processing Record 34 of Set 1 | consett
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | los negros
# Processing Record 39 of Set 1 | xichang
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | salalah
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | youghal
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 1 | kiunga
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | cedar city
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | hoyerswerda
# Processing Record 3 of Set 2 | bukachacha
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | vostok
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | caravelas
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | mantua
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | okhotsk
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | garden city
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 2 | thilogne
# City not found. Skipping...
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | baghmara
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | huacho
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | shangqiu
# Processing Record 30 of Set 2 | kribi
# Processing Record 31 of Set 2 | marrakesh
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | bukama
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | riyadh
# Processing Record 36 of Set 2 | buraydah
# Processing Record 37 of Set 2 | tigil
# Processing Record 38 of Set 2 | tura
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | abu dhabi
# Processing Record 42 of Set 2 | prince rupert
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | aykhal
# Processing Record 49 of Set 2 | barbastro
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | nemuro
# Processing Record 2 of Set 3 | hofn
# Processing Record 3 of Set 3 | boa vista
# Processing Record 4 of Set 3 | sao sebastiao
# Processing Record 5 of Set 3 | coihaique
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | gioia tauro
# Processing Record 11 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 3 | mandalgovi
# Processing Record 13 of Set 3 | leshukonskoye
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | mogadishu
# Processing Record 16 of Set 3 | samarai
# Processing Record 17 of Set 3 | springbok
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | barcelos
# Processing Record 20 of Set 3 | preobrazheniye
# Processing Record 21 of Set 3 | passau
# Processing Record 22 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 3 | altay
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 3 | vardo
# Processing Record 26 of Set 3 | port augusta
# Processing Record 27 of Set 3 | shimoda
# Processing Record 28 of Set 3 | klaksvik
# Processing Record 29 of Set 3 | alugan
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | san francisco menendez
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | kuznechnoye
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 3 | skala
# Processing Record 38 of Set 3 | aklavik
# Processing Record 39 of Set 3 | marovoay
# Processing Record 40 of Set 3 | miraflores
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | mitchell
# Processing Record 43 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | byron bay
# Processing Record 46 of Set 3 | oum hadjer
# Processing Record 47 of Set 3 | badin
# Processing Record 48 of Set 3 | strathpeffer
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | kargasok
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | tuy hoa
# Processing Record 3 of Set 4 | manokwari
# Processing Record 4 of Set 4 | bilibino
# Processing Record 5 of Set 4 | pestovo
# Processing Record 6 of Set 4 | marquette
# Processing Record 7 of Set 4 | inirida
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | forestville
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 4 | berbera
# Processing Record 17 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | batie
# Processing Record 21 of Set 4 | aquiraz
# Processing Record 22 of Set 4 | ust-tsilma
# Processing Record 23 of Set 4 | caribou
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | ketchikan
# Processing Record 26 of Set 4 | breyten
# Processing Record 27 of Set 4 | parola
# Processing Record 28 of Set 4 | halifax
# Processing Record 29 of Set 4 | bria
# Processing Record 30 of Set 4 | road town
# Processing Record 31 of Set 4 | mehamn
# Processing Record 32 of Set 4 | lujan
# Processing Record 33 of Set 4 | kundiawa
# Processing Record 34 of Set 4 | ayan
# Processing Record 35 of Set 4 | kaeo
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | kushiro
# Processing Record 39 of Set 4 | puerto narino
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | ilhabela
# Processing Record 42 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 4 | shache
# Processing Record 44 of Set 4 | unity
# Processing Record 45 of Set 4 | pandan
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | matata
# Processing Record 49 of Set 4 | tsabong
# Processing Record 50 of Set 4 | paamiut
# Processing Record 1 of Set 5 | mae hong son
# Processing Record 2 of Set 5 | zhangye
# Processing Record 3 of Set 5 | ilam
# Processing Record 4 of Set 5 | wamba
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | dikson
# Processing Record 8 of Set 5 | sola
# Processing Record 9 of Set 5 | fort nelson
# Processing Record 10 of Set 5 | jinchang
# Processing Record 11 of Set 5 | maniitsoq
# Processing Record 12 of Set 5 | haines junction
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | semey
# Processing Record 16 of Set 5 | benjamin aceval
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | chhindwara
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | goundam
# Processing Record 23 of Set 5 | saldanha
# Processing Record 24 of Set 5 | rorvik
# Processing Record 25 of Set 5 | torbay
# Processing Record 26 of Set 5 | taltal
# Processing Record 27 of Set 5 | jimma
# Processing Record 28 of Set 5 | kifri
# Processing Record 29 of Set 5 | carbondale
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | riberalta
# Processing Record 32 of Set 5 | novosheshminsk
# Processing Record 33 of Set 5 | sitka
# Processing Record 34 of Set 5 | deputatskiy
# Processing Record 35 of Set 5 | hailar
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | morristown
# Processing Record 39 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 5 | mayor pablo lagerenza
# Processing Record 41 of Set 5 | tenenkou
# Processing Record 42 of Set 5 | san borja
# Processing Record 43 of Set 5 | praya
# Processing Record 44 of Set 5 | waingapu
# Processing Record 45 of Set 5 | provideniya
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | den helder
# Processing Record 48 of Set 5 | keti bandar
# Processing Record 49 of Set 5 | kemijarvi
# Processing Record 50 of Set 5 | whitley bay
# Processing Record 1 of Set 6 | vuktyl
# Processing Record 2 of Set 6 | chardara
# Processing Record 3 of Set 6 | zhigansk
# Processing Record 4 of Set 6 | sambava
# Processing Record 5 of Set 6 | nuuk
# Processing Record 6 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 6 | gorontalo
# Processing Record 8 of Set 6 | marawi
# Processing Record 9 of Set 6 | kangasala
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | bom jesus
# Processing Record 12 of Set 6 | ayr
# Processing Record 13 of Set 6 | sibolga
# Processing Record 14 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 15 of Set 6 | sao jose da coroa grande
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | tazovskiy
# Processing Record 18 of Set 6 | tagusao
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | el alto
# Processing Record 21 of Set 6 | sochi
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | lavrentiya
# Processing Record 24 of Set 6 | northam
# Processing Record 25 of Set 6 | fukuma
# Processing Record 26 of Set 6 | campina verde
# Processing Record 27 of Set 6 | olafsvik
# Processing Record 28 of Set 6 | muros
# Processing Record 29 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 6 | meiganga
# Processing Record 31 of Set 6 | saint-francois
# Processing Record 32 of Set 6 | shubarkuduk
# Processing Record 33 of Set 6 | binabalian
# Processing Record 34 of Set 6 | olds
# Processing Record 35 of Set 6 | lambarene
# Processing Record 36 of Set 6 | georgetown
# Processing Record 37 of Set 6 | teguldet
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | mar del plata
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | araouane
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | san antonio
# Processing Record 45 of Set 6 | chenzhou
# Processing Record 46 of Set 6 | fuyang
# Processing Record 47 of Set 6 | sosnovka
# Processing Record 48 of Set 6 | mahebourg
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | harlingen
# Processing Record 1 of Set 7 | marsh harbour
# Processing Record 2 of Set 7 | fort frances
# Processing Record 3 of Set 7 | scottsbluff
# Processing Record 4 of Set 7 | la ronge
# Processing Record 5 of Set 7 | osakarovka
# Processing Record 6 of Set 7 | comodoro rivadavia
# Processing Record 7 of Set 7 | tazlar
# Processing Record 8 of Set 7 | high level
# Processing Record 9 of Set 7 | opuwo
# Processing Record 10 of Set 7 | honningsvag
# Processing Record 11 of Set 7 | tahta
# Processing Record 12 of Set 7 | mandla
# Processing Record 13 of Set 7 | bakel
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | muscat
# Processing Record 16 of Set 7 | rize
# Processing Record 17 of Set 7 | sokolka
# Processing Record 18 of Set 7 | savannah bight
# Processing Record 19 of Set 7 | mankono
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | sao miguel do araguaia
# Processing Record 22 of Set 7 | havelock
# Processing Record 23 of Set 7 | baykit
# Processing Record 24 of Set 7 | lodja
# Processing Record 25 of Set 7 | neringa
# Processing Record 26 of Set 7 | rio gallegos
# Processing Record 27 of Set 7 | talesh
# City not found. Skipping...
# Processing Record 28 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 7 | navalcarnero
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | nipawin
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 7 | pueblo nuevo
# Processing Record 37 of Set 7 | santa rosa
# Processing Record 38 of Set 7 | nemours
# Processing Record 39 of Set 7 | tambacounda
# Processing Record 40 of Set 7 | beloha
# Processing Record 41 of Set 7 | tarauaca
# Processing Record 42 of Set 7 | batagay-alyta
# Processing Record 43 of Set 7 | port-cartier
# Processing Record 44 of Set 7 | djambala
# Processing Record 45 of Set 7 | rabo de peixe
# Processing Record 46 of Set 7 | jahanabad
# Processing Record 47 of Set 7 | longyearbyen
# Processing Record 48 of Set 7 | plettenberg bay
# Processing Record 49 of Set 7 | matay
# Processing Record 50 of Set 7 | rabat
# Processing Record 1 of Set 8 | sicamous
# Processing Record 2 of Set 8 | callaway
# Processing Record 3 of Set 8 | ngorongoro
# Processing Record 4 of Set 8 | digby
# Processing Record 5 of Set 8 | aras
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | betong
# Processing Record 9 of Set 8 | badnawar
# Processing Record 10 of Set 8 | asau
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | akyab
# Processing Record 13 of Set 8 | tual
# Processing Record 14 of Set 8 | lorengau
# Processing Record 15 of Set 8 | griffith
# Processing Record 16 of Set 8 | asyut
# Processing Record 17 of Set 8 | kysyl-syr
# Processing Record 18 of Set 8 | khash
# Processing Record 19 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 20 of Set 8 | killarney
# Processing Record 21 of Set 8 | santa isabel
# Processing Record 22 of Set 8 | gravdal
# Processing Record 23 of Set 8 | krasnyy yar
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | padang
# Processing Record 26 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 27 of Set 8 | broome
# Processing Record 28 of Set 8 | komsomolskiy
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | causapscal
# Processing Record 31 of Set 8 | tynda
# Processing Record 32 of Set 8 | lagos
# Processing Record 33 of Set 8 | saint pete beach
# Processing Record 34 of Set 8 | henties bay
# Processing Record 35 of Set 8 | rafsanjan
# Processing Record 36 of Set 8 | majene
# Processing Record 37 of Set 8 | talcahuano
# Processing Record 38 of Set 8 | knysna
# Processing Record 39 of Set 8 | sobolevo
# Processing Record 40 of Set 8 | toamasina
# Processing Record 41 of Set 8 | nhulunbuy
# Processing Record 42 of Set 8 | winton
# Processing Record 43 of Set 8 | mackay
# Processing Record 44 of Set 8 | alice springs
# Processing Record 45 of Set 8 | banjar
# Processing Record 46 of Set 8 | champerico
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | ovsyanka
# Processing Record 49 of Set 8 | kafue
# Processing Record 50 of Set 8 | orland park
# Processing Record 1 of Set 9 | marsa matruh
# Processing Record 2 of Set 9 | verkhoyansk
# Processing Record 3 of Set 9 | bambous virieux
# Processing Record 4 of Set 9 | gao
# Processing Record 5 of Set 9 | nanortalik
# Processing Record 6 of Set 9 | anito
# Processing Record 7 of Set 9 | alibag
# Processing Record 8 of Set 9 | amlame
# Processing Record 9 of Set 9 | okato
# Processing Record 10 of Set 9 | awbari
# Processing Record 11 of Set 9 | znamensk
# Processing Record 12 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 13 of Set 9 | burica
# City not found. Skipping...
# Processing Record 14 of Set 9 | salisbury
# Processing Record 15 of Set 9 | lucea
# Processing Record 16 of Set 9 | arawa
# Processing Record 17 of Set 9 | lubao
# Processing Record 18 of Set 9 | asfi
# Processing Record 19 of Set 9 | nouadhibou
# Processing Record 20 of Set 9 | sakakah
# Processing Record 21 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 9 | tautira
# Processing Record 23 of Set 9 | san andres
# Processing Record 24 of Set 9 | turukhansk
# Processing Record 25 of Set 9 | ferkessedougou
# Processing Record 26 of Set 9 | koungou
# Processing Record 27 of Set 9 | kodiak
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | mayo
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | bonnyville
# Processing Record 33 of Set 9 | sijunjung
# Processing Record 34 of Set 9 | kenai
# Processing Record 35 of Set 9 | kahului
# Processing Record 36 of Set 9 | burns lake
# Processing Record 37 of Set 9 | bengkulu
# Processing Record 38 of Set 9 | itaqui
# Processing Record 39 of Set 9 | cap malheureux
# Processing Record 40 of Set 9 | bambanglipuro
# Processing Record 41 of Set 9 | avera
# Processing Record 42 of Set 9 | tiarei
# Processing Record 43 of Set 9 | mezen
# Processing Record 44 of Set 9 | sinnamary
# Processing Record 45 of Set 9 | pingliang
# Processing Record 46 of Set 9 | bonthe
# Processing Record 47 of Set 9 | nisia floresta
# Processing Record 48 of Set 9 | port moresby
# Processing Record 49 of Set 9 | ponta delgada
# Processing Record 50 of Set 9 | manggar
# Processing Record 1 of Set 10 | minden
# Processing Record 2 of Set 10 | troitskoye
# Processing Record 3 of Set 10 | schweinfurt
# Processing Record 4 of Set 10 | ladario
# Processing Record 5 of Set 10 | yuanping
# Processing Record 6 of Set 10 | cauquenes
# Processing Record 7 of Set 10 | batagay
# Processing Record 8 of Set 10 | alekseyevsk
# Processing Record 9 of Set 10 | kariba
# Processing Record 10 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 11 of Set 10 | san luis
# Processing Record 12 of Set 10 | lensk
# Processing Record 13 of Set 10 | acarau
# Processing Record 14 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 10 | jalu
# Processing Record 16 of Set 10 | podor
# Processing Record 17 of Set 10 | laramie
# Processing Record 18 of Set 10 | vilcun
# Processing Record 19 of Set 10 | urumqi
# Processing Record 20 of Set 10 | herat
# Processing Record 21 of Set 10 | santa fe
# Processing Record 22 of Set 10 | nuevo jalapa
# City not found. Skipping...
# Processing Record 23 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 10 | nova olimpia
# Processing Record 25 of Set 10 | ugoofaaru
# Processing Record 26 of Set 10 | ondjiva
# Processing Record 27 of Set 10 | itarema
# Processing Record 28 of Set 10 | ippy
# Processing Record 29 of Set 10 | lasa
# Processing Record 30 of Set 10 | brookline
# Processing Record 31 of Set 10 | along
# Processing Record 32 of Set 10 | saint-augustin
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | muroto
# Processing Record 35 of Set 10 | berlevag
# Processing Record 36 of Set 10 | kismayo
# Processing Record 37 of Set 10 | korla
# Processing Record 38 of Set 10 | dongfeng
# Processing Record 39 of Set 10 | luganville
# Processing Record 40 of Set 10 | zlobin
# Processing Record 41 of Set 10 | noumea
# Processing Record 42 of Set 10 | eureka
# Processing Record 43 of Set 10 | porto ferreira
# Processing Record 44 of Set 10 | luderitz
# Processing Record 45 of Set 10 | poronaysk
# Processing Record 46 of Set 10 | magoula
# Processing Record 47 of Set 10 | mujiayingzi
# Processing Record 48 of Set 10 | aksu
# Processing Record 49 of Set 10 | gilgit
# Processing Record 50 of Set 10 | maningrida
# Processing Record 1 of Set 11 | jerome
# Processing Record 2 of Set 11 | cascais
# Processing Record 3 of Set 11 | ola
# Processing Record 4 of Set 11 | labuhan
# Processing Record 5 of Set 11 | vanimo
# Processing Record 6 of Set 11 | okha
# Processing Record 7 of Set 11 | siraha
# Processing Record 8 of Set 11 | wajima
# Processing Record 9 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 11 | phillipsburg
# Processing Record 11 of Set 11 | eyl
# Processing Record 12 of Set 11 | namibe
# Processing Record 13 of Set 11 | corinto
# Processing Record 14 of Set 11 | progreso
# Processing Record 15 of Set 11 | pakwach
# City not found. Skipping...
# Processing Record 16 of Set 11 | fuzhou
# Processing Record 17 of Set 11 | afogados da ingazeira
# Processing Record 18 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 11 | straumen
# Processing Record 20 of Set 11 | anloga
# Processing Record 21 of Set 11 | los llanos de aridane
# Processing Record 22 of Set 11 | mount gambier
# Processing Record 23 of Set 11 | ponnani
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | tarko-sale
# Processing Record 26 of Set 11 | navolato
# Processing Record 27 of Set 11 | hambantota
# Processing Record 28 of Set 11 | pulandian
# Processing Record 29 of Set 11 | porto velho
# Processing Record 30 of Set 11 | vao
# Processing Record 31 of Set 11 | svetlaya
# Processing Record 32 of Set 11 | arua
# Processing Record 33 of Set 11 | tateyama
# Processing Record 34 of Set 11 | holme
# Processing Record 35 of Set 11 | vega de alatorre
# Processing Record 36 of Set 11 | agirish
# Processing Record 37 of Set 11 | san patricio
# Processing Record 38 of Set 11 | sao filipe
# Processing Record 39 of Set 11 | hervey bay
# Processing Record 40 of Set 11 | pringsewu
# Processing Record 41 of Set 11 | ballina
# Processing Record 42 of Set 11 | viedma
# Processing Record 43 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 44 of Set 11 | matara
# Processing Record 45 of Set 11 | yar-sale
# Processing Record 46 of Set 11 | kandrian
# Processing Record 47 of Set 11 | atar
# Processing Record 48 of Set 11 | tobol
# Processing Record 49 of Set 11 | mahibadhoo
# Processing Record 50 of Set 11 | shingu
# Processing Record 1 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 2 of Set 12 | kant
# Processing Record 3 of Set 12 | tonota
# Processing Record 4 of Set 12 | krasnoselkup
# Processing Record 5 of Set 12 | tayu
# Processing Record 6 of Set 12 | carauari
# Processing Record 7 of Set 12 | smithers
# Processing Record 8 of Set 12 | port hedland
# Processing Record 9 of Set 12 | gamba
# Processing Record 10 of Set 12 | chapais
# Processing Record 11 of Set 12 | jensen beach
# Processing Record 12 of Set 12 | walvis bay
# Processing Record 13 of Set 12 | vestmanna
# Processing Record 14 of Set 12 | manaure
# Processing Record 15 of Set 12 | husavik
# Processing Record 16 of Set 12 | revda
# Processing Record 17 of Set 12 | whitehorse
# Processing Record 18 of Set 12 | bodden town
# Processing Record 19 of Set 12 | bantou
# Processing Record 20 of Set 12 | doka
# Processing Record 21 of Set 12 | madang
# Processing Record 22 of Set 12 | santiago de cao
# Processing Record 23 of Set 12 | storforshei
# Processing Record 24 of Set 12 | nishihara
# Processing Record 25 of Set 12 | makakilo city
# Processing Record 26 of Set 12 | galle
# Processing Record 27 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 12 | taybad
# Processing Record 29 of Set 12 | ovalle
# Processing Record 30 of Set 12 | puro
# Processing Record 31 of Set 12 | vallenar
# Processing Record 32 of Set 12 | raudeberg
# Processing Record 33 of Set 12 | lazaro cardenas
# Processing Record 34 of Set 12 | bairiki
# Processing Record 35 of Set 12 | barabai
# Processing Record 36 of Set 12 | milkovo
# Processing Record 37 of Set 12 | aksarka
# Processing Record 38 of Set 12 | sault sainte marie
# Processing Record 39 of Set 12 | birjand
# Processing Record 40 of Set 12 | bonavista
# Processing Record 41 of Set 12 | mitu
# Processing Record 42 of Set 12 | havoysund
# Processing Record 43 of Set 12 | high rock
# Processing Record 44 of Set 12 | kendari
# Processing Record 45 of Set 12 | manta
# Processing Record 46 of Set 12 | zabol
# Processing Record 47 of Set 12 | wanning
# Processing Record 48 of Set 12 | conil
# Processing Record 49 of Set 12 | entre rios
# Processing Record 50 of Set 12 | taoudenni
# Processing Record 1 of Set 13 | conde
# Processing Record 2 of Set 13 | mbandaka
# Processing Record 3 of Set 13 | miri
# Processing Record 4 of Set 13 | bellary
# Processing Record 5 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 13 | nador
# Processing Record 7 of Set 13 | ati
# Processing Record 8 of Set 13 | luwuk
# Processing Record 9 of Set 13 | seydi
# Processing Record 10 of Set 13 | tamandare
# Processing Record 11 of Set 13 | caucaia
# Processing Record 12 of Set 13 | inuvik
# Processing Record 13 of Set 13 | vila do maio
# Processing Record 14 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 15 of Set 13 | dunyapur
# Processing Record 16 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 13 | meadow lake
# Processing Record 18 of Set 13 | samfya
# Processing Record 19 of Set 13 | luoyang
# Processing Record 20 of Set 13 | manzhouli
# Processing Record 21 of Set 13 | sao felix do xingu
# Processing Record 22 of Set 13 | olinda
# Processing Record 23 of Set 13 | caxito
# Processing Record 24 of Set 13 | jonesboro
# Processing Record 25 of Set 13 | bongandanga
# Processing Record 26 of Set 13 | alto baudo
# City not found. Skipping...
# Processing Record 27 of Set 13 | sur
# Processing Record 28 of Set 13 | issenye
# Processing Record 29 of Set 13 | gimli
# Processing Record 30 of Set 13 | rocha
# Processing Record 31 of Set 13 | rajauri
# Processing Record 32 of Set 13 | rongcheng
# Processing Record 33 of Set 13 | am timan
# Processing Record 34 of Set 13 | sivaki
# Processing Record 35 of Set 13 | nelson bay
# Processing Record 36 of Set 13 | banda aceh
# Processing Record 37 of Set 13 | kedrovyy
# Processing Record 38 of Set 13 | doha
# Processing Record 39 of Set 13 | belmonte
# Processing Record 40 of Set 13 | qaqortoq
# Processing Record 41 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 13 | teya
# Processing Record 43 of Set 13 | lopatino
# Processing Record 44 of Set 13 | ziro
# Processing Record 45 of Set 13 | palana
# Processing Record 46 of Set 13 | arboletes
# Processing Record 47 of Set 13 | sisimiut
# Processing Record 48 of Set 13 | troitsko-pechorsk
# Processing Record 49 of Set 13 | fairbanks
# Processing Record 50 of Set 13 | thinadhoo
# Processing Record 1 of Set 14 | zyryanovsk
# Processing Record 2 of Set 14 | southbridge
# Processing Record 3 of Set 14 | port macquarie
# Processing Record 4 of Set 14 | naze
# Processing Record 5 of Set 14 | kot addu
# Processing Record 6 of Set 14 | aguilar de la frontera
# Processing Record 7 of Set 14 | monte patria
# Processing Record 8 of Set 14 | kidal
# Processing Record 9 of Set 14 | nouakchott
# Processing Record 10 of Set 14 | jalalpur pirwala
# Processing Record 11 of Set 14 | brookhaven
# Processing Record 12 of Set 14 | maceio
# Processing Record 13 of Set 14 | savelugu
# Processing Record 14 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 14 | hargeysa
# Processing Record 16 of Set 14 | nizhneangarsk
# Processing Record 17 of Set 14 | bolshevik
# Processing Record 18 of Set 14 | kyra
# Processing Record 19 of Set 14 | kabanjahe
# Processing Record 20 of Set 14 | westport
# Processing Record 21 of Set 14 | felanitx
# Processing Record 22 of Set 14 | wah
# Processing Record 23 of Set 14 | rawson
# Processing Record 24 of Set 14 | tuntum
# Processing Record 25 of Set 14 | jacqueville
# Processing Record 26 of Set 14 | fernie
# Processing Record 27 of Set 14 | santa maria
# Processing Record 28 of Set 14 | starobaltachevo
# Processing Record 29 of Set 14 | kieta
# Processing Record 30 of Set 14 | qunduz
# Processing Record 31 of Set 14 | chicama
# Processing Record 32 of Set 14 | sechura
# Processing Record 33 of Set 14 | alyangula
# Processing Record 34 of Set 14 | morehead
# Processing Record 35 of Set 14 | hamilton
# Processing Record 36 of Set 14 | martapura
# Processing Record 37 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 14 | half moon bay
# Processing Record 39 of Set 14 | palmer
# Processing Record 40 of Set 14 | jiaocheng
# Processing Record 41 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 14 | mindif
# Processing Record 43 of Set 14 | mukhen
# Processing Record 44 of Set 14 | abashiri
# Processing Record 45 of Set 14 | novokizhinginsk
# Processing Record 46 of Set 14 | gualeguaychu
# Processing Record 47 of Set 14 | angangxi
# City not found. Skipping...
# Processing Record 48 of Set 14 | vanavara
# Processing Record 49 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 50 of Set 14 | mizdah
# Processing Record 1 of Set 15 | evanston
# Processing Record 2 of Set 15 | saquarema
# Processing Record 3 of Set 15 | sokoni
# Processing Record 4 of Set 15 | colesberg
# Processing Record 5 of Set 15 | gurun
# Processing Record 6 of Set 15 | hualmay
# Processing Record 7 of Set 15 | itupiranga
# Processing Record 8 of Set 15 | adre
# Processing Record 9 of Set 15 | swan hill
# Processing Record 10 of Set 15 | college
# Processing Record 11 of Set 15 | parabel
# Processing Record 12 of Set 15 | blora
# Processing Record 13 of Set 15 | jacareacanga
# Processing Record 14 of Set 15 | leh
# Processing Record 15 of Set 15 | agadir
# Processing Record 16 of Set 15 | celina
# Processing Record 17 of Set 15 | mocuba
# Processing Record 18 of Set 15 | los alamos
# Processing Record 19 of Set 15 | jiazi
# Processing Record 20 of Set 15 | la sarre
# Processing Record 21 of Set 15 | winchester
# Processing Record 22 of Set 15 | zaplyusye
# City not found. Skipping...
# Processing Record 23 of Set 15 | kanniyakumari
# Processing Record 24 of Set 15 | verkhoturye
# Processing Record 25 of Set 15 | bardiyah
# Processing Record 26 of Set 15 | faya
# Processing Record 27 of Set 15 | callaguip
# Processing Record 28 of Set 15 | birin
# Processing Record 29 of Set 15 | mecca
# Processing Record 30 of Set 15 | bandarbeyla
# Processing Record 31 of Set 15 | imbituba
# Processing Record 32 of Set 15 | gainesville
# Processing Record 33 of Set 15 | kupino
# Processing Record 34 of Set 15 | kununurra
# Processing Record 35 of Set 15 | tshikapa
# Processing Record 36 of Set 15 | dakar
# Processing Record 37 of Set 15 | governador valadares
# Processing Record 38 of Set 15 | saint anthony
# Processing Record 39 of Set 15 | broken hill
# Processing Record 40 of Set 15 | juneau
# Processing Record 41 of Set 15 | cabedelo
# Processing Record 42 of Set 15 | azanka
# Processing Record 43 of Set 15 | kazerun
# Processing Record 44 of Set 15 | ussel
# Processing Record 45 of Set 15 | lavagna
# Processing Record 46 of Set 15 | kondinskoye
# Processing Record 47 of Set 15 | boyolangu
# Processing Record 48 of Set 15 | ushtobe
# Processing Record 49 of Set 15 | dingle
# Processing Record 50 of Set 15 | karakol
# Processing Record 1 of Set 16 | akureyri
# Processing Record 2 of Set 16 | wawa
# Processing Record 3 of Set 16 | maldonado
# Processing Record 4 of Set 16 | ardalstangen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      rikitea      PF -23.1203 -134.9692     77.79        73          78
# 1     khatanga      RU  71.9667  102.5000    -23.73       100         100
# 2  new norfolk      AU -42.7826  147.0587     72.66        89         100
# 3    busselton      AU -33.6500  115.3333     70.05        57           0
# 4       avarua      CK -21.2078 -159.7750     82.45        78         100
# 5    hithadhoo      MV  -0.6000   73.0833     80.62        78         100
# 6       sumter      US  28.7086  -82.0831     68.99        70          15
# 7       barrow      US  71.2906 -156.7887     -7.58        84           0
# 8        arlit      NE  18.7369    7.3853     62.15        17          18
# 9      ajaccio      FR  42.0000    8.9167     43.29        93           0
#
#    Wind Speed Current Description                 Date
# 0       13.11          light rain  2022-01-06 23:43:01
# 1        5.57     overcast clouds  2022-01-06 23:43:01
# 2        2.35     overcast clouds  2022-01-06 23:43:02
# 3       16.11           clear sky  2022-01-06 23:43:02
# 4        6.91     overcast clouds  2022-01-06 23:43:03
# 5        6.42     overcast clouds  2022-01-06 23:43:03
# 6        5.61          few clouds  2022-01-06 23:43:04
# 7       10.36           clear sky  2022-01-06 23:41:26
# 8        9.64          few clouds  2022-01-06 23:43:04
# 9        6.91           clear sky  2022-01-06 23:43:04

# %%
# 8. Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
